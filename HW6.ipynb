# %% [markdown]
# <a href="https://colab.research.google.com/github/curikim123/curikim123/blob/master/HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.linear_model as lm

# %%
! if [ ! -e shhs1.csv ] ; \
  then wget https://raw.githubusercontent.com/curikim123/curikim123/master/shhs1.csv; \
fi

# %%
df = pd.read_csv("shhs1.csv")

df= df[['rdi4p', 'bmi_s1']]

df = df.dropna()

# %%
df.head(4)
# Out:
#        rdi4p     bmi_s1
# 0   1.438083  21.777553
# 1  17.802198  32.950680
# 2   4.853556  24.114150
# 3   0.797342  20.185185

# %%
x = df['bmi_s1']
y = np.log(df['rdi4p']+1)


print(st.linregress(x = x, y = y))
sns.regplot(x, y, df.dropna())
# Out:
# LinregressResult(slope=0.07648599151230175, intercept=-0.46304140227711144, rvalue=0.36743643840291873, pvalue=1.2027582935043808e-183, stderr=0.002551125352413094)

# %%
y= 0.07648599151230175*30-0.46304140227711144
y
# Out:
# 1.831538343091941
